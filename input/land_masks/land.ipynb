# %%
import xarray as xr

# %%
ds1 = xr.open_mfdataset(
    '/home/links/ct715/Isca/input/land_masks/era_land_T42.nc'
)
ds1
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 64, lon: 128)
# Coordinates:
#   * lat        (lat) float32 -87.86 -85.1 -82.31 -79.53 ... 82.31 85.1 87.86
#   * lon        (lon) float32 0.0 2.812 5.625 8.438 ... 348.8 351.6 354.4 357.2
# Data variables:
#     zsurf      (lat, lon) float32 dask.array<chunksize=(64, 128), meta=np.ndarray>
#     land_mask  (lat, lon) float32 dask.array<chunksize=(64, 128), meta=np.ndarray>

# %%
ds2 = xr.open_mfdataset(
    '/home/links/ct715/Isca/input/land_masks/era-spectral7_T42_64x128.out.nc'
)
ds2
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 64, lon: 128)
# Coordinates:
#   * lat        (lat) float32 -87.86 -85.1 -82.31 -79.53 ... 82.31 85.1 87.86
#   * lon        (lon) float32 0.0 2.812 5.625 8.438 ... 348.8 351.6 354.4 357.2
# Data variables:
#     zsurf      (lat, lon) float32 dask.array<chunksize=(64, 128), meta=np.ndarray>
#     land_mask  (lat, lon) float32 dask.array<chunksize=(64, 128), meta=np.ndarray>

# %%
ds3 = xr.open_mfdataset(
    '/home/links/ct715/Isca/input/land_masks/land_t42.nc'
)
ds3
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 64, lon: 128)
# Coordinates:
#   * lat        (lat) float32 -87.86 -85.1 -82.31 -79.53 ... 82.31 85.1 87.86
#   * lon        (lon) float32 0.0 2.812 5.625 8.438 ... 348.8 351.6 354.4 357.2
# Data variables:
#     zsurf      (lat, lon) float32 dask.array<chunksize=(64, 128), meta=np.ndarray>
#     land_mask  (lat, lon) float32 dask.array<chunksize=(64, 128), meta=np.ndarray>

# %%
ds1.equals(ds3)
# Out:
# False
